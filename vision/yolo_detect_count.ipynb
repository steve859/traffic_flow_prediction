# %%
# !pip install ultralytics
# Out:
# ^C
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached ultralytics-8.3.252-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pyyaml-6.0.3-cp314-cp314-win_amd64.whl.metadata (2.4 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached scipy-1.17.0-cp314-cp314-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached psutil-7.2.1-cp37-abi3-win_amd64.whl.metadata (23 kB)
# ...
#   Using cached polars-1.37.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.61.1-cp314-cp314-win_amd64.whl.metadata (116 kB)
# ...

# %%
import os
import re
import csv
from datetime import datetime, timedelta
from pathlib import Path

import torch
from ultralytics import YOLO
from PIL import Image

# %% [markdown]
# Config

# %%
# Notebook có thể chạy ở local/WSL/Colab, nên dùng Path + auto-resolve
PROJECT_ROOT = Path.cwd()

# Mặc định (khi chạy trong repo ở thư mục vision/)
IMAGE_ROOT = Path("..") / "data"   # chứa cam1/, cam2/, ...
OUTPUT_CSV = Path("..") / "yolo_counts.csv"
MODEL_PATH = Path("detector") / "yolov8n_multiclass_best.pt"

CONF_THRES = 0.3
IMG_SIZE = 480        # CPU-friendly
DEVICE = "cpu"        # ép CPU cho chắc

# Múi giờ Việt Nam (UTC+7): cộng thêm 7 tiếng vào timestamp đọc từ filename
TZ_SHIFT_HOURS = 7

# Các lớp cần xuất ra CSV (tên sẽ được match theo model.names)
CANONICAL_CLASSES = ("motorbike", "car", "bus", "truck")


def _auto_resolve_file(filename: str) -> Path | None:
    # Thử vài vị trí phổ biến trước (nhanh)
    quick_bases = [
        Path.cwd(),
        Path.cwd() / "traffic_flow_prediction",
        Path.cwd().parent,
        Path("/content"),
        Path("/kaggle/input") if Path("/kaggle").exists() else None,
    ]
    for base in [b for b in quick_bases if b is not None]:
        for candidate in (
            base / filename,
            base / "vision" / "detector" / filename,
            base / "detector" / filename,
        ):
            if candidate.exists():
                return candidate
    # Fallback: tìm trong cây thư mục hiện tại (có thể chậm nếu folder quá lớn)
    try:
        for p in Path.cwd().rglob(filename):
            return p
    except Exception:
        pass
    return None


def _auto_resolve_image_root() -> Path | None:
    # Mục tiêu: folder chứa cam1/, cam2/, ...
    quick_candidates = [
        Path.cwd() / "data",
        Path.cwd().parent / "data",
        Path.cwd() / "traffic_flow_prediction" / "data",
        Path("/content") / "traffic_flow_prediction" / "data",
    ]
    for candidate in quick_candidates:
        if candidate.exists() and (candidate / "cam1").exists():
            return candidate
    # Fallback: tìm thư mục 'data' có cam1
    try:
        for p in Path.cwd().rglob("data"):
            if p.is_dir() and (p / "cam1").exists():
                return p
    except Exception:
        pass
    return None


_model_found = _auto_resolve_file("yolov8n_multiclass_best.pt")
if _model_found is not None:
    MODEL_PATH = _model_found
_image_root_found = _auto_resolve_image_root()
if _image_root_found is not None:
    IMAGE_ROOT = _image_root_found

# %% [markdown]
# 3### VS Code chạy nhưng kernel là Colab (remote)
# Nếu bạn dùng **VS Code Notebook** nhưng chọn **kernel Colab**, thì code sẽ chạy trên máy remote (thường có `CWD=/content`).
# Khi đó, kernel **không truy cập được** đường dẫn ổ đĩa Windows như `D:\...`.
# Bạn cần upload/copy file `.pt` (và dữ liệu ảnh) lên filesystem của kernel, rồi trỏ `MODEL_PATH` / `IMAGE_ROOT` tới các file/folder đó.

# %%
# Upload file vào kernel (hữu ích khi dùng VS Code + Colab kernel remote)
from pathlib import Path

print("CWD:", Path.cwd())
Path("detector").mkdir(parents=True, exist_ok=True)
Path("data").mkdir(parents=True, exist_ok=True)

def upload_pt_to_detector(expected_name: str = "yolov8n_multiclass_best.pt"):
    """
    Upload weight .pt vào ./detector và cập nhật MODEL_PATH.
    Hỗ trợ ipywidgets (Jupyter/VS Code) hoặc google.colab.files (Colab runtime).
    """
    try:
        import ipywidgets as widgets  # type: ignore
        from IPython.display import display  # type: ignore

        uploader = widgets.FileUpload(accept=".pt", multiple=False)
        display(uploader)
        print("Chọn file .pt để upload (FileUpload widget)...")

        def _on_change(change):
            if not uploader.value:
                return
            item = next(iter(uploader.value.values()))
            name = item.get("metadata", {}).get("name", expected_name)
            content = item.get("content")
            if not content:
                print("Upload failed: empty content")
                return
            dst = Path("detector") / name
            dst.write_bytes(content)
            global MODEL_PATH
            MODEL_PATH = dst.resolve()
            print("Uploaded ->", MODEL_PATH)
            print("Exists:", MODEL_PATH.exists())

        uploader.observe(_on_change, names="value")
        return
    except Exception as e_widget:
        # Fallback: google.colab.files (nếu kernel là Colab)
        try:
            from google.colab import files  # type: ignore
            uploaded = files.upload()
            for name in uploaded.keys():
                dst = Path("detector") / name
                dst.write_bytes(uploaded[name])
                global MODEL_PATH
                MODEL_PATH = dst.resolve()
            print("Updated MODEL_PATH:", MODEL_PATH)
            print("Exists:", MODEL_PATH.exists())
            return
        except Exception as e_colab:
            print("Không thể dùng upload tự động.")
            print("- ipywidgets error:", e_widget)
            print("- colab.files error:", e_colab)
            print("Gợi ý: hãy copy file .pt lên máy kernel và đặt vào ./detector/")


def upload_zip_to_data():
    """
    Upload 1 file .zip chứa thư mục data/cam1, cam2... vào ./data
    (Tuỳ chọn, nếu kernel remote không thấy dữ liệu local).
    """
    try:
        import ipywidgets as widgets  # type: ignore
        from IPython.display import display  # type: ignore
        import zipfile
        import io

        uploader = widgets.FileUpload(accept=".zip", multiple=False)
        display(uploader)
        print("Chọn file .zip để upload (ví dụ zip của folder data/)...")

        def _on_change(change):
            if not uploader.value:
                return
            item = next(iter(uploader.value.values()))
            content = item.get("content")
            if not content:
                print("Upload failed: empty content")
                return
            zf = zipfile.ZipFile(io.BytesIO(content))
            zf.extractall(Path.cwd())
            print("Extracted zip to:", Path.cwd())
            print("data exists:", Path("data").exists())

        uploader.observe(_on_change, names="value")
    except Exception as e:
        print("Zip upload requires ipywidgets.")
        print("Error:", e)


# Gọi khi cần:
# upload_pt_to_detector()
# upload_zip_to_data()
# Out:
# CWD: /content

# %% [markdown]
# Utils

# %%
def parse_timestamp(filename):
    """
    Expect filename like:
    2025-01-12_06-45-10.jpg
    """
    match = re.search(r"\d{4}-\d{2}-\d{2}_\d{2}-\d{2}-\d{2}", filename)
    if not match:
        raise ValueError(f"Cannot parse timestamp from {filename}")
    ts = datetime.strptime(match.group(), "%Y-%m-%d_%H-%M-%S")
    return ts + timedelta(hours=TZ_SHIFT_HOURS)


def _norm_name(name: str) -> str:
    return re.sub(r"[^a-z0-9]+", "", str(name).strip().lower())


# Alias để match linh hoạt tên lớp trong model multi-class
CLASS_ALIASES = {
    "motorbike": {"motorbike", "motorcycle", "xemay", "xe_may", "bike"},
    "car": {"car", "oto", "o_to", "automobile"},
    "bus": {"bus", "xebuyt", "xe_buyt", "coach"},
    "truck": {"truck", "xetai", "xe_tai", "lorry"},
}

# Chuẩn hoá alias trước để so sánh nhanh
_CLASS_ALIASES_NORM = {k: {_norm_name(v) for v in vs} for k, vs in CLASS_ALIASES.items()}


def count_vehicles_multiclass(model, image_path):
    """
    Trả về dict count theo CANONICAL_CLASSES từ 1 model duy nhất.
    """
    results = model.predict(
        source=image_path,
        conf=CONF_THRES,
        imgsz=IMG_SIZE,
        device=DEVICE,
        verbose=False,
    )
    counts = {k: 0 for k in CANONICAL_CLASSES}
    if not results or results[0].boxes is None or results[0].boxes.cls is None:
        return counts

    names = getattr(model, "names", {}) or {}
    for cls_id in results[0].boxes.cls.tolist():
        cls_id = int(cls_id)
        raw_name = names.get(cls_id, str(cls_id))
        norm = _norm_name(raw_name)
        for canonical, alias_norms in _CLASS_ALIASES_NORM.items():
            if norm in alias_norms:
                counts[canonical] += 1
                break
    return counts

# %% [markdown]
# Main

# %%
def main():
    if not MODEL_PATH.exists():
        raise FileNotFoundError(
            "MODEL_PATH not found.\n"
            f"- Kernel CWD: {Path.cwd()}\n"
            f"- MODEL_PATH: {MODEL_PATH}\n\n"
            "Nếu bạn dùng VS Code nhưng kernel Colab (remote), kernel sẽ KHÔNG thấy file ở ổ D: của Windows.\n"
            "Cách xử lý: chạy Cell 6 để upload file .pt vào ./detector/, rồi chạy lại Cell 4 (Config) và Cell 10 (Main)."
        )
    if not IMAGE_ROOT.exists():
        raise FileNotFoundError(
            "IMAGE_ROOT not found.\n"
            f"- Kernel CWD: {Path.cwd()}\n"
            f"- IMAGE_ROOT: {IMAGE_ROOT}\n\n"
            "Nếu kernel remote không thấy dữ liệu local, hãy upload/đưa folder data/ lên kernel (có thể dùng Cell 6 upload zip), "
            "hoặc đổi sang kernel local để đọc trực tiếp data trong máy bạn."
        )

    print("🚀 Loading YOLO model (single multiclass)...")
    model = YOLO(str(MODEL_PATH))

    rows = []

    for cam_dir in sorted(IMAGE_ROOT.iterdir()):
        if not cam_dir.is_dir():
            continue
        if not re.match(r"^cam\d+$", cam_dir.name, flags=re.IGNORECASE):
            continue

        print(f"\n📷 Processing {cam_dir.name}...")

        for img_path in sorted(cam_dir.iterdir()):
            if img_path.suffix.lower() not in (".jpg", ".png"):
                continue

            timestamp = parse_timestamp(img_path.name)  # đã +7 giờ VN

            counts = count_vehicles_multiclass(model, str(img_path))
            motorbike = counts.get("motorbike", 0)
            car = counts.get("car", 0)
            bus = counts.get("bus", 0)
            truck = counts.get("truck", 0)

            total = motorbike + car + bus + truck
            rows.append([
                cam_dir.name,
                timestamp.strftime("%Y-%m-%d %H:%M:%S"),
                motorbike,
                car,
                bus,
                truck,
                total,
            ])

    # write CSV
    print("\n💾 Writing CSV...")
    OUTPUT_CSV.parent.mkdir(parents=True, exist_ok=True)
    with open(OUTPUT_CSV, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["camera_id", "timestamp", "motorbike", "car", "bus", "truck", "total"])
        writer.writerows(rows)

    print(f"✅ DONE. Saved to {OUTPUT_CSV}")
    print(f"Total frames processed: {len(rows)}")


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2799667501.py in <cell line: 0>()
#      66
#      67 if __name__ == "__main__":
# ---> 68     main()
#
# /tmp/ipython-input-2799667501.py in main()
#       1 def main():
#       2     if not MODEL_PATH.exists():
# ----> 3         raise FileNotFoundError(
#       4             "MODEL_PATH not found.\n"
#       5             f"- Kernel CWD: {Path.cwd()}\n"
#
# FileNotFoundError: MODEL_PATH not found.
# - Kernel CWD: /content
# - MODEL_PATH: detector/yolov8n_multiclass_best.pt
#
# Nếu bạn dùng VS Code nhưng kernel Colab (remote), kernel sẽ KHÔNG thấy file ở ổ D: của Windows.
# Cách xử lý: chạy Cell 6 để upload file .pt vào ./detector/, rồi chạy lại Cell 4 (Config) và Cell 10 (Main).
